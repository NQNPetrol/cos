# %%
import pandas as pd
from personal_api import importar_datos

# %%
#pasando archivo de xls a xlsx
borrador_personal = pd.read_excel('C:/wamp64/www/cos/app/Scripts/personal/planilla_personal.xls')
borrador_personal.to_excel('planilla_personal.xlsx', index=False)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'

# %%
#leyendo el archivo y guardandolo en un dataframe
personal = pd.read_excel('C:/wamp64/www/cos/app/Scripts/personal/planilla_personal.xlsx')

#manteniendo solo las columnas necesarias
personal = personal[['legajo', 'nombres', 'apellido', 'fecha_ing', 'tipo_doc', 'nro_doc', 'convenio']]

# %%
personal = personal.rename(columns={'nombres': 'nombre'})

# %%
# config de la api
API_URL = "http://localhost:8000/api/personal"
API_KEY = ""

# %%
resultado = importar_datos(personal, API_URL)
print(resultado['message'])
# Out:
# Importacion exitosa

# %%
personal.head()
# Out:
#    legajo            nombre  apellido  fecha_ing tipo_doc   nro_doc  \
# 0       1  GUILLERMO MARTIN      TORO 2019-03-25       DU  18365141
# 1       3            NESTOR    ISADOR 2019-06-18       DU  21915520
# 2       5             GUIDO  LOPARDO* 2008-11-06       DU  12345678
# 3       6            NELSON  FLANDERS 2013-03-12       DU  29901081
# 4       9         SEBASTIAN     RENDO 2012-07-10       DU  16315583
#
#              convenio
# 0  CONVENIO SEGURIDAD
# 1  CONVENIO SEGURIDAD
# 2  CONVENIO SEGURIDAD
# 3  CONVENIO SEGURIDAD
# 4  CONVENIO SEGURIDAD
